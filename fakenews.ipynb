# %%
import numpy as np

# %%
import pandas as pd

# %%
true = pd.read_csv("True.csv")

# %%
fake = pd.read_csv("Fake.csv")

# %%
true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
true['label'] = 1
fake['label'] = 0

# %%
true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date  label
# 0  December 31, 2017       1
# 1  December 29, 2017       1
# 2  December 31, 2017       1
# 3  December 30, 2017       1
# 4  December 29, 2017       1

# %%
news = pd.concat([fake,true], axis =0)  # that is merging the data row wise

# %%
news.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  label
# 0  December 31, 2017      0
# 1  December 31, 2017      0
# 2  December 30, 2017      0
# 3  December 29, 2017      0
# 4  December 25, 2017      0

# %%
news.tail()
# Out:
#                                                    title  \
# 21412  'Fully committed' NATO backs new U.S. approach...
# 21413  LexisNexis withdrew two products from Chinese ...
# 21414  Minsk cultural hub becomes haven from authorities
# 21415  Vatican upbeat on possibility of Pope Francis ...
# 21416  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text    subject  \
# 21412  BRUSSELS (Reuters) - NATO allies on Tuesday we...  worldnews
# 21413  LONDON (Reuters) - LexisNexis, a provider of l...  worldnews
# 21414  MINSK (Reuters) - In the shadow of disused Sov...  worldnews
# 21415  MOSCOW (Reuters) - Vatican Secretary of State ...  worldnews
# 21416  JAKARTA (Reuters) - Indonesia will buy 11 Sukh...  worldnews
#
#                    date  label
# 21412  August 22, 2017       1
# 21413  August 22, 2017       1
# 21414  August 22, 2017       1
# 21415  August 22, 2017       1
# 21416  August 22, 2017       1

# %% [markdown]
# Let's check if there is any null value in there or not

# %%
news.isnull().sum()
# Out:
# title      0
# text       0
# subject    0
# date       0
# label      0
# dtype: int64

# %% [markdown]
# we do not want things like title, subject and date so lets drop it.

# %%
news = news.drop(["title","subject","date"], axis = 1)

# %%
news.head()
# Out:
#                                                 text  label
# 0  Donald Trump just couldn t wish all Americans ...      0
# 1  House Intelligence Committee Chairman Devin Nu...      0
# 2  On Friday, it was revealed that former Milwauk...      0
# 3  On Christmas day, Donald Trump announced that ...      0
# 4  Pope Francis used his annual Christmas Day mes...      0

# %% [markdown]
# Here the data is looking very clean and shuffle so now we need to take the data and reshuffle it.

# %%
news = news.sample(frac = 1)

# %%
news.head()
# Out:
#                                                     text  label
# 5598   SAN FRANCISCO (Reuters) - U.S. federal appeals...      1
# 10856  WASHINGTON (Reuters) - U.S. President Barack O...      1
# 20546  The self proclaimed  feminist  apparently has ...      0
# 16110  BELFAST (Reuters) - The British government on ...      1
# 22724  When it comes to interpreting current events, ...      0

# %%
news.reset_index(inplace = True)

# %%
news.head()
# Out:
#    index                                               text  label
# 0   5598  SAN FRANCISCO (Reuters) - U.S. federal appeals...      1
# 1  10856  WASHINGTON (Reuters) - U.S. President Barack O...      1
# 2  20546  The self proclaimed  feminist  apparently has ...      0
# 3  16110  BELFAST (Reuters) - The British government on ...      1
# 4  22724  When it comes to interpreting current events, ...      0

# %% [markdown]
# still this index is creating problem so lets drop it

# %%
news = news.drop(columns = "index")

# %% [markdown]
# here it is already droped
#
# like here i made a mistake of dropping the wrong column so to avoid it we need to create a copy of the table.

# %%
news.head()
# Out:
#                                                 text  label
# 0  SAN FRANCISCO (Reuters) - U.S. federal appeals...      1
# 1  WASHINGTON (Reuters) - U.S. President Barack O...      1
# 2  The self proclaimed  feminist  apparently has ...      0
# 3  BELFAST (Reuters) - The British government on ...      1
# 4  When it comes to interpreting current events, ...      0

# %% [markdown]
# here ml algorithms read numerical data better than categorical data so we need to conver it into numerical vector

# %%
import re

# %% [markdown]
# To convert the text into readable form we import it regular expression

# %%
def wordopt(text):
    # convert it into lower case
    text = text.lower()
    
    # remove urls
    text = re.sub(r'http\S+|www\S+|https\S+', '', text)
    
    #remove html tag
    text = re.sub(r'<.*?>', '', text)
    
    #remove punctuations
    text = re.sub(r'[^\w\s]', '',text)
    
    #remove digits
    text = re.sub(r'\d', '', text)
    
    #remove new line character
    text = re.sub(r'\n', ' ', text)
    
    return text

# %%
news['text'] = news['text'].apply(wordopt)

# %%
news['text']
# Out:
# 0        san francisco reuters  us federal appeals cour...
# 1        washington reuters  us president barack obama ...
# 2        the self proclaimed  feminist  apparently has ...
# 3        belfast reuters  the british government on mon...
# 4        when it comes to interpreting current events n...
#                                ...
# 44893    former acting attorney general sally yates was...
# 44894    seoul reuters  north korean foreign minister r...
# 44895    seoultokyo reuters  detonating a nucleartipped...
# 44896    donald trump took his angry little fingers to ...
# 44897    sen bernie sanders i vt could not say on wedne...
# Name: text, Length: 44898, dtype: object

# %%
x = news['text']

y = news['label']

# %%
x
# Out:
# 0        san francisco reuters  us federal appeals cour...
# 1        washington reuters  us president barack obama ...
# 2        the self proclaimed  feminist  apparently has ...
# 3        belfast reuters  the british government on mon...
# 4        when it comes to interpreting current events n...
#                                ...
# 44893    former acting attorney general sally yates was...
# 44894    seoul reuters  north korean foreign minister r...
# 44895    seoultokyo reuters  detonating a nucleartipped...
# 44896    donald trump took his angry little fingers to ...
# 44897    sen bernie sanders i vt could not say on wedne...
# Name: text, Length: 44898, dtype: object

# %%
y
# Out:
# 0        1
# 1        1
# 2        0
# 3        1
# 4        0
#         ..
# 44893    0
# 44894    1
# 44895    1
# 44896    0
# 44897    0
# Name: label, Length: 44898, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.3)

# %%
x_train.shape
# Out:
# (31428,)

# %%
x_test.shape
# Out:
# (13470,)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorization = TfidfVectorizer()

# %%
xv_train = vectorization.fit_transform(x_train)

# %%
xv_test = vectorization.transform(x_test)

# %%
xv_train
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 6443461 stored elements and shape (31428, 174391)>

# %%
xv_test
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 2736420 stored elements and shape (13470, 174391)>

# %%
from sklearn.linear_model import LogisticRegression

# %%
LR = LogisticRegression()

# %%
LR.fit(xv_train, y_train)
# Out:
# LogisticRegression()

# %%
pred_lr = LR.predict(xv_test)

# %%
LR.score(xv_test, y_test)
# Out:
# 0.9881959910913141

# %%
from sklearn.metrics import classification_report

# %%
classification_report(y_test, pred_lr)
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.99      0.99      0.99      7095\n           1       0.99      0.99      0.99      6375\n\n    accuracy                           0.99     13470\n   macro avg       0.99      0.99      0.99     13470\nweighted avg       0.99      0.99      0.99     13470\n'

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
DTC = DecisionTreeClassifier()

# %%
DTC.fit(xv_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred_dtc = DTC.predict(xv_test)

# %%
DTC.score(xv_test, y_test)
# Out:
# 0.9965850037119525

# %%
classification_report(y_test, pred_dtc)
# Out:
# '              precision    recall  f1-score   support\n\n           0       1.00      1.00      1.00      7095\n           1       1.00      1.00      1.00      6375\n\n    accuracy                           1.00     13470\n   macro avg       1.00      1.00      1.00     13470\nweighted avg       1.00      1.00      1.00     13470\n'

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
RFC = RandomForestClassifier()

# %%
RFC.fit(xv_train, y_train)
# Out:
# RandomForestClassifier()

# %%
pred_rfc = RFC.predict(xv_test)

# %%
RFC.score(xv_test, y_test)
# Out:
# 0.9864884929472902

# %%
classification_report(y_test, pred_rfc)
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.99      0.98      0.99      7095\n           1       0.98      0.99      0.99      6375\n\n    accuracy                           0.99     13470\n   macro avg       0.99      0.99      0.99     13470\nweighted avg       0.99      0.99      0.99     13470\n'

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
GBC = GradientBoostingClassifier()

# %%
GBC.fit(xv_train, y_train)
# Out:
# GradientBoostingClassifier()

# %%
pred_gbc = GBC.predict(xv_test)

# %%
GBC.score(xv_test, y_test)
# Out:
# 0.9955456570155902

# %%
classification_report(y_test, pred_gbc)
# Out:
# '              precision    recall  f1-score   support\n\n           0       1.00      0.99      1.00      7095\n           1       0.99      1.00      1.00      6375\n\n    accuracy                           1.00     13470\n   macro avg       1.00      1.00      1.00     13470\nweighted avg       1.00      1.00      1.00     13470\n'

# %%
def output_lable(n):
    if n == 0:
        return "It is a Fake News"
    elif n == 1:
        return "It is a Genuine News"

# %%
def manual_testing(news):
    testing_news = {"text":[news]}
    new_def_test = pd.DataFrame(testing_news)
    new_def_test["text"] = new_def_test["text"].apply(wordopt)
    new_x_test = new_def_test["text"]
    new_xv_test = vectorization.transform(new_x_test)
    pred_LR = LR.predict(new_xv_test)
    pred_DTC = DTC.predict(new_xv_test)
    pred_RFC = RFC.predict(new_xv_test)
    pred_GBC = GBC.predict(new_xv_test)
    
    return print("\n\nLR Prediction: {} \nDTC Prediction: {} \nRFC Prediction: {} \nGBC Prediction: {}".format(output_lable(pred_LR[0]),output_lable(pred_DTC[0]),output_lable(pred_RFC[0]),output_lable(pred_GBC[0])))

# %%
news_article = str(input())

# %%
manual_testing(news_article)
# Out:
# LR Prediction: It is a Fake News
# DTC Prediction: It is a Fake News
# RFC Prediction: It is a Genuine News
# GBC Prediction: It is a Fake News
